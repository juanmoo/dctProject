# %%
import sys, os
sys.path.append(os.path.realpath('./src'))
from utils import *
from svd import *

# %%
## Paths ##
tmp_dir = os.path.realpath('./tmp/')

# %%
img = load_grayscale(os.path.join(tmp_dir, 'backyard.jpg'))
img = square_resize(img, 1024)

# %%
gs_arr = np.array(img).T[0].T

# %%
image_from_grayscale_array(gs_arr)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x1024 at 0x111897E80>

# %%
img_fact = IMG_SVD(gs_arr, block_size=8, frac=0)
decoded = image_from_grayscale_array(img_fact.recreate())

decoded
# Out:
# <PIL.Image.Image image mode=RGB size=1024x1024 at 0x1118847F0>

# %%
img_fact.calculate_size()/calculate_image_size(img)
# Out:
# 0.015625

# %%
img.size
# Out:
# (3024, 3024)
